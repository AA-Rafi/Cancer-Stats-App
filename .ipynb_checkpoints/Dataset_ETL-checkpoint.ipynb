# %%
# Import dependencies
import pandas as pd
import numpy as np
from pathlib import Path

# %%
rates_df = pd.read_csv('Datasets/Number_and_rates_of_new_cases_of_primary_cancer_by_cancer_type_age_group_and_sex.csv', low_memory=False)
rates_df.head()
# Out:
#    REF_DATE     GEO           DGUID        Age group         Sex
# 0      1992  Canada  2016A000011124  Total, all ages  Both sexes  \
# 1      1993  Canada  2016A000011124  Total, all ages  Both sexes
# 2      1994  Canada  2016A000011124  Total, all ages  Both sexes
# 3      1995  Canada  2016A000011124  Total, all ages  Both sexes
# 4      1996  Canada  2016A000011124  Total, all ages  Both sexes
#
#                   Primary types of cancer (ICD-O-3)
# 0  Total, all primary sites of cancer [C00.0-C80.9]  \
# 1  Total, all primary sites of cancer [C00.0-C80.9]
# 2  Total, all primary sites of cancer [C00.0-C80.9]
# 3  Total, all primary sites of cancer [C00.0-C80.9]
# 4  Total, all primary sites of cancer [C00.0-C80.9]
#
#               Characteristics     UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID
# 0  Number of new cancer cases  Number     223         units          0  \
# 1  Number of new cancer cases  Number     223         units          0
# ...
